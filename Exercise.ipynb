# %% [markdown]
# # 1. Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df= pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # 2. Shuffle:

# %%
# Shuffle the DataFrame
df.sample( frac=1, random_state=10, axis=0).reset_index()
# Out:
#      index        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0       87  0.583893       0.555556      0.125000       0.576271
# 1      111  0.744966            NaN      0.291667       0.728814
# 2       10  0.067114       0.305556      0.708333       0.084746
# 3       91  0.610738       0.500000      0.416667       0.610169
# 4       49  0.328859       0.194444      0.541667       0.067797
# ..     ...       ...            ...           ...            ...
# 145    113  0.758389       0.388889      0.208333       0.677966
# 146     64  0.429530       0.361111      0.375000       0.440678
# 147     15  0.100671       0.388889      1.000000       0.084746
# 148    125  0.838926       0.805556      0.500000       0.847458
# 149      9  0.060403       0.166667      0.458333       0.084746
#
#      PetalWidthCm          Species
# 0        0.500000  Iris-versicolor
# 1        0.750000   Iris-virginica
# 2        0.041667      Iris-setosa
# 3        0.541667  Iris-versicolor
# 4        0.041667      Iris-setosa
# ..            ...              ...
# 145      0.791667   Iris-virginica
# 146      0.500000  Iris-versicolor
# 147      0.125000      Iris-setosa
# 148      0.708333   Iris-virginica
# 149      0.000000      Iris-setosa
#
# [150 rows x 7 columns]

# %% [markdown]
# # 3. Descriptive Stats

# %%
df.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.00000     147.000000    150.000000     147.000000    150.000000
# mean     0.50000       0.430272      0.439167       0.466505      0.457778
# std      0.29158       0.230908      0.180664       0.302008      0.317984
# min      0.00000       0.000000      0.000000       0.000000      0.000000
# 25%      0.25000       0.222222      0.333333       0.093220      0.083333
# 50%      0.50000       0.416667      0.416667       0.576271      0.500000
# 75%      0.75000       0.583333      0.541667       0.694915      0.708333
# max      1.00000       1.000000      1.000000       1.000000      1.000000

# %% [markdown]
# # 4. Shape:

# %%
#number of rows and columns
row, columns =df.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 135
# Number of columns: 6

# %% [markdown]
# # 5. Dropping columns:

# %%
#creating a new dataframe without the 'Id' column
df = df.drop(['Id'], axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0         0.222222      0.625000       0.067797      0.041667     Iris-setosa
# 1         0.166667      0.416667       0.067797      0.041667     Iris-setosa
# 2         0.111111      0.500000       0.050847      0.041667     Iris-setosa
# 3         0.083333      0.458333       0.084746      0.041667     Iris-setosa
# 4         0.194444      0.666667       0.067797      0.041667     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       0.666667      0.416667       0.711864      0.916667  Iris-virginica
# 146       0.555556      0.208333       0.677966      0.750000  Iris-virginica
# 147       0.611111      0.416667       0.711864      0.791667  Iris-virginica
# 148       0.527778      0.583333       0.745763      0.916667  Iris-virginica
# 149       0.444444      0.416667       0.694915      0.708333  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 6. Histograms:

# %%
#creating a basic histogram for individual columns
new_df.hist(bins= 50)
plt.savefig('Iris histograms.png')

# %%
new_df["SepalLengthCm"].hist(bins= 10)
plt.savefig('Iris-SepalLengthCm hist.png')

# %%
new_df["SepalWidthCm"].hist(bins= 20)
plt.savefig('Iris-SepalWidthCm hist.png')

# %%
new_df["PetalLengthCm"].hist(bins= 20)
plt.savefig('Iris-PetalLengthCm hist.png')

# %%
new_df["PetalWidthCm"].hist(bins= 20)
plt.savefig('Iris-PetalWidthCm hist.png')

# %%
new_df["Species"].hist(bins= 20)
plt.savefig('Iris-Species hist.png')

# %% [markdown]
# # 7. Scatter Plots:

# %%
#Draw a scatter plot for SepalLengthCm & SepalWidthCm
df.plot.scatter(x = 'SepalLengthCm', y = 'SepalWidthCm', title = 'SepalLenthCm vs. SepalWidthCm')
plt.savefig('SepalLenthCm vs. SepalWidthCm Scatter.png')

# %%
#Draw a scatter plot for SepalLengthCm & PetalLengthCm
df.plot.scatter(x = 'SepalLengthCm', y = 'PetalLengthCm', title = 'SepalLenthCm vs. PetalLengthCm')
plt.savefig('SepalLenthCm vs. PetalLengthCm Scatter.png')

# %% [markdown]
# # 8. Unique category values:

# %%
#count of each category in Species Column
print(df["Species"].value_counts())
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     47
# Name: Species, dtype: int64

# %% [markdown]
# # 9. Nan Values:

# %%
#checking nan values in the dataframe
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.PetalLengthCm[62]
# Out:
# 3.7523809523809524

# %%
nan_dict = {}

all_columns =  ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
for column in df[all_columns]:
     if df[column].isna().any():
        # Store the indices of missing values
        nan_indices = df[df[column].isna()].index.tolist()
        nan_dict[column] = nan_indices
        
         # Check if column is numerical or categorical
        if df[column].dtype == np.number:
            # Replace missing values with the mean of the column
            df[column].fillna(df[column].mean(), inplace=True)
        else:
            # Drop rows with missing values in categorical column
            df.dropna(subset=[column], inplace=True)

# Reset the row index
df = df.reset_index(drop=True)

# Print the updated DataFrame
print(df)

# Print the nan_dict
print(nan_dict)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 136  146            6.7           3.0            5.2           2.3
# 137  147            6.3           2.5            5.0           1.9
# 138  148            6.5           3.0            5.2           2.0
# 139  149            6.2           3.4            5.4           2.3
# 140  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
#
# [141 rows x 6 columns]
# {}

# %% [markdown]
# # 10. Outliers:

# %%
 # Calculate mean and standard deviation
 mean = df['SepalWidthCm'].mean()
 std = df['SepalWidthCm'].std()

 # Calculate the value/score that is 2 standard deviation above the mean
 value = mean + 2 * std

# Find row indices with values outside the range
indices = df.loc[df.SepalWidthCm >= value].index.tolist()

# Drop rows with identified indices
df = df.drop(indices)

# Reset the row index
df = df.reset_index(drop=True)

df.shape
# Out:
# (135, 6)

# %% [markdown]
# # 11. New Feature

# %%
# Calculate petal area and create the 'PetalArea' column
df['PetalArea'] = df['PetalLengthCm'] * df['PetalWidthCm']
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 130  146            6.7           3.0            5.2           2.3
# 131  147            6.3           2.5            5.0           1.9
# 132  148            6.5           3.0            5.2           2.0
# 133  149            6.2           3.4            5.4           2.3
# 134  150            5.9           3.0            5.1           1.8
#
#             Species  PetalArea
# 0       Iris-setosa       0.28
# 1       Iris-setosa       0.28
# 2       Iris-setosa       0.26
# 3       Iris-setosa       0.30
# 4       Iris-setosa       0.28
# ..              ...        ...
# 130  Iris-virginica      11.96
# 131  Iris-virginica       9.50
# 132  Iris-virginica      10.40
# 133  Iris-virginica      12.42
# 134  Iris-virginica       9.18
#
# [135 rows x 7 columns]

# %% [markdown]
# # 12. Noisy Column:

# %%
#Set the seed value
np.random.seed(42)

#number of rows in a dataframe 
rows, columns = df.shape

#Generate the array
random_arr = np.random.normal(5,3, rows)

#convert the array to a pandas dataframe
rand_df = pd.DataFrame(random_arr, columns= ['RandomNumbers'])

#Concatenate the new Dataframe with the Iris Dataframe
df_concatenated = pd.concat([df, rand_df], axis = 1)

#check that the last 5 random numbers are generated
df_concatenated.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 130  146            6.7           3.0            5.2           2.3
# 131  147            6.3           2.5            5.0           1.9
# 132  148            6.5           3.0            5.2           2.0
# 133  149            6.2           3.4            5.4           2.3
# 134  150            5.9           3.0            5.1           1.8
#
#             Species  PetalArea  RandomNumbers
# 130  Iris-virginica      11.96       0.348010
# 131  Iris-virginica       9.50       5.205689
# 132  Iris-virginica      10.40       1.813089
# 133  Iris-virginica      12.42       6.420777
# 134  Iris-virginica       9.18       2.241727

# %% [markdown]
# # 13. Normalize numerical columns:

# %%
# Create copies of the original DataFrame
df_minmax = df.copy()
df_z = df.copy()

# apply normalization techniques

numerical_columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
for column in df[numerical_columns]:
   df_minmax [column] = (df_minmax[column] - df_minmax[column].min()) / (df_minmax[column].max() - df_minmax[column].min())    
  
# view normalized data
print(df_minmax)

# apply normalization techniques
for column in df[numerical_columns]:
  df_z[column] = (df_z[column] - df_z[column].mean()) / df_z[column].std()    
  
# view normalized data   
display(df_z)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       0.235294      0.882353       0.067797      0.041667
# 1      2       0.176471      0.588235       0.067797      0.041667
# 2      3       0.117647      0.705882       0.050847      0.041667
# 3      4       0.088235      0.647059       0.084746      0.041667
# 4      5       0.205882      0.941176       0.067797      0.041667
# ..   ...            ...           ...            ...           ...
# 130  146       0.705882      0.588235       0.711864      0.916667
# 131  147       0.588235      0.294118       0.677966      0.750000
# 132  148       0.647059      0.588235       0.711864      0.791667
# 133  149       0.558824      0.823529       0.745763      0.916667
# 134  150       0.470588      0.588235       0.694915      0.708333
#
#             Species  PetalArea
# 0       Iris-setosa       0.28
# 1       Iris-setosa       0.28
# 2       Iris-setosa       0.26
# 3       Iris-setosa       0.30
# 4       Iris-setosa       0.28
# ..              ...        ...
# 130  Iris-virginica      11.96
# 131  Iris-virginica       9.50
# 132  Iris-virginica      10.40
# 133  Iris-virginica      12.42
# 134  Iris-virginica       9.18
#
# [135 rows x 7 columns]
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1      -0.908657      1.448809      -1.436084     -1.385805
# 1      2      -1.156478      0.051743      -1.436084     -1.385805
# 2      3      -1.404299      0.610570      -1.495019     -1.385805
# 3      4      -1.528209      0.331156      -1.377149     -1.385805
# 4      5      -1.032568      1.728222      -1.436084     -1.385805
# ..   ...            ...           ...            ...           ...
# 130  146       1.073909      0.051743       0.803451      1.422456
# 131  147       0.578267     -1.345323       0.685581      0.887549
# 132  148       0.826088      0.051743       0.803451      1.021276
# 133  149       0.454357      1.169396       0.921321      1.422456
# 134  150       0.082626      0.051743       0.744516      0.753823
#
#             Species  PetalArea
# 0       Iris-setosa       0.28
# 1       Iris-setosa       0.28
# 2       Iris-setosa       0.26
# 3       Iris-setosa       0.30
# 4       Iris-setosa       0.28
# ..              ...        ...
# 130  Iris-virginica      11.96
# 131  Iris-virginica       9.50
# 132  Iris-virginica      10.40
# 133  Iris-virginica      12.42
# 134  Iris-virginica       9.18
#
# [135 rows x 7 columns]

# %% [markdown]
# # 14. Saving Dataframes:

# %%
#save the new dataframes to csv
df_minmax.to_csv('df_minmax.csv', index=False)
df_z.to_csv('df_z.csv', index=False)
